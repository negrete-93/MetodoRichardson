# %% [markdown]
# <a href="https://colab.research.google.com/github/negrete-93/MetodoRichardson/blob/main/M%C3%A9todo_de_Richardson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Método de Richardson
#
# Es una técnica numérica que sirve para mejorar la precisión de una aproximación numérica usando el mismo método pero con distintos tamaños de paso.

# %%
import sympy as sp
import numpy as np

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # necesario para 3D
from matplotlib import cm  # colormap

# %%
#definimos la matriz
def f(x):
    return np.sin(np.pi*x)

A = sp.Matrix([[3,-1, 0, 0, 0, 0, 0, 0, 0],
              [-1, 3,-1, 0, 0, 0, 0, 0, 0],
              [0, -1, 3,-1, 0, 0, 0, 0, 0],
              [0, 0, -1, 3,-1, 0, 0, 0, 0],
              [0, 0, 0, -1, 3,-1, 0, 0, 0],
              [0, 0, 0, 0, -1, 3,-1, 0, 0],
              [0, 0, 0, 0, 0, -1, 3,-1, 0],
              [0, 0, 0, 0, 0, 0, -1, 3,-1],
              [0, 0, 0, 0, 0, 0, 0, -1, 3,]])

# %% [markdown]
# Ejercicio 1: Codificar la matriz A de manera más simple.

# %%
b = sp.Matrix([f(0.1), f(0.2), f(0.3), f(0.4), f(0.5), f(0.6), f(0.7), f(0.8), f(0.9)])

# %% [markdown]
# Solución:

# %%
n = 9

x = sp.zeros(n,1)

#Parámetro de Richardson
w=0.25

#Tolerancia y max iteaciones
tol = 1e-6
max_iter = 1000

#Iteración de Richardson

for k in range(max_iter):
  r = b - A * x
  X_n = x + w * r

  error = (X_n - x).norm()

  if error < tol:
    break

  x = X_n

print("Solución aproximada:")
print(x)

#Validamos la solución exacta
x_exact = A.LUsolve(b)

print("\nSolución exacta:")
print(x_exact)

print("\nError:")
print((x - x_exact).norm())
# Out:
# Solución aproximada:
# Matrix([[0.281464822493908], [0.535377907081379], [0.736884471926506], [0.866259650483455], [0.910839298865197], [0.866259650483455], [0.736884471926506], [0.535377907081379], [0.281464822493908]])
#
# Solución exacta:
# Matrix([[0.281465217775586], [0.535378658951812], [0.736885506787377], [0.866260867035370], [0.910840578023580], [0.866260867035370], [0.736885506787377], [0.535378658951812], [0.281465217775587]])
#
# Error:
# 2.86028509790169e-6

# %% [markdown]
# Ejercicio 2: Definir las entradas de b de manera más simple (quizás con un bucle).

# %%
n= len(b)

h= 1/(n+1)

b=sp.Matrix([f(h*(i+1)) for i in range(n)])
b
# Out:
# Matrix([
# [0.309016994374947],
# [0.587785252292473],
# [0.809016994374947],
# [0.951056516295154],
# [              1.0],
# [0.951056516295154],
# [0.809016994374947],
# [0.587785252292473],
# [0.309016994374948]])

# %%
def richardson(A, b, j):
    S = []
    b_1 = b.copy()

    for i in range(j+1):
        S.append(np.array(b_1, dtype=float).reshape(-1))  # vector fila
        sol = A.LUsolve(b_1)
        b_1 = sol

    return np.array(S)   # matriz resultado

# %% [markdown]
# Ejercicio 4: Graficar para un valor particular de t > 0 y comparar contra la gráfica de la solución exacta (quizás necesite calcularla).

# %%
from scipy.linalg import lu_factor, lu_solve
r=0.4
h=1.0/(n+1)
k = r * h**2

x_internal= np.linspace(1/(n+1), n/(n+1), n)

# %%
from scipy.linalg import lu_factor, lu_solve
r=0.4
h=1.0/(n+1)
k = r * h**2

x_internal= np.linspace(1/(n+1), n/(n+1), n)

# %%
L = np.diag([2]*n) + np.diag([-1]*(n-1), -1) + np.diag([-1]*(n-1), 1)
M = np.eye(n) + r * L
t_objetivo_plot = 0.3

j = int(t_objetivo_plot / k)
if j < 1:
    j = 1

b_np = np.array(b).astype(float)
U = richardson_implicito(M, b_np, j)
t_objetivo = t_objetivo_plot

t_objetivo = 0.3
n_obj = int(t_objetivo/k)

u_exacta = np.exp(-np.pi**2 *j*k) * np.sin(np.pi * x_internal)

# %%
# %matplotlib inline
plt.figure(figsize=(10,5.5))
plt.plot(x_internal, U[j], 'o-', label='Numérica (Richardson)', markersize=8, lw=2)
plt.plot(x_internal, u_exacta, '--', label=r'Exacta ', lw=3)
plt.title(f'Comparación en t = {t_objetivo}', fontsize=16)
plt.xlabel('x', fontsize=14)
plt.ylabel('u(x,t)', fontsize=14)
plt.legend(fontsize=12)
plt.grid(alpha=0.4)
plt.show()
print("k =", k)
print("j =", j)
print("U.shape =", U.shape)
print("n_obj =", n_obj)
# Out:
# <div id='7e87a57b-70ae-4577-9d26-1d7ce42a43fc'></div>
# <div id='14a56f2a-3eb9-448d-976d-7020ba05abec'></div>
# <div id='7c84032e-ee8b-41c5-978d-18007c0cef0b'></div>
# <div id='3d448fa4-9f09-4919-8fe8-e462bdc3f83d'></div>
# <div id='989c9aed-d48c-4cfa-bc05-a883ce5410bd'></div>
# <div id='b88b1c4b-f20e-48ca-89c9-f718e22e0cbc'></div>
# <div id='eca32889-4f56-468a-8ab2-b6882d45edb9'></div>
# <div id='dd9286f7-9b71-4c45-837b-b00c7c4926ee'></div>
# <div id='2faaeeb1-c45c-45ce-9a11-af9de8004387'></div>
# <div id='df6e4091-307d-42ad-80e4-a260d08a6b9c'></div>
# <div id='e98df9c2-a35f-4e1e-b200-838b56c42ec4'></div>
# <div id='2385027d-302d-421e-bf8d-35d145e692f7'></div>
# <div id='f6baa90e-c743-4b94-bb72-33c020badf26'></div>
# <div id='c7b8b4ab-0f2a-46e3-90a2-d5decacaf9ed'></div>
# <div id='a0476e37-1766-4b0f-a4c1-a73a7af25e8d'></div>
# <div id='82b6aac7-0120-4261-8916-29fe277c31a6'></div>
# <div id='a3ff7b94-3d92-4ba9-9eab-e53fd4246e47'></div>
# ...

# %% [markdown]
# Ejercicio 5:¿Es necesario resolver el sistema de 9 x 9 o podemos hacer una simplificación?

# %% [markdown]
# No es necesario ya que la matriz es tridiagonal y simétrica definida positiva, lo que nos permite usar otros métodos especializados como el algoritmo de Thomas en lugar de la factorización LU general. Además, dado que la condición inicial es proporcional a un autovector del operador, la solución puede obtenerse analíticamente sin resolver el sistema completo, usando separación de variables.

# %%
j = 20 # Número de pasos en el tiempo

# %%
U=richardson(A, b, j)
x = np.linspace(0, 1, 9) #Número de nodos internos en X
y = np.linspace(0, 0.6, j+1) #Debe coincidir con el tamaño de j por k (tiempo)
X, Y = np.meshgrid(x, y)

# %%
# Mapa de colores
plt.figure(figsize=(8, 6))
contour = plt.contourf(X, Y, U, levels=25, cmap=cm.viridis)
plt.colorbar(contour)
plt.title('Solución numérica de un problema de Dirichlet')
plt.xlabel('x')
plt.ylabel('y')
plt.axis('equal')
plt.show()

# %% [markdown]
# Explica la gráfica:
#
# El mapa de colores muestra cómo la temperatura disminuye con el tiempo, difundiéndose y atenuándose suavemente conforme aumenta t. Se observa que el persil senoidal conserva su forma, pero su amplitud decrece exponencialmente como se predice en la solución analítica de la ecuación de calor

# %%
# %matplotlib inline
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X, Y, U, cmap=cm.viridis, edgecolor='k')
ax.set_title('Solución de la ecuación del calor con Dirichlet')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('u(x, y)')
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
# Out:
# <div id='6289a5eb-1993-4ea7-8753-dd606d25f54b'></div>
# <div id='f179b0fc-97db-45bd-9441-a1f3b0dba288'></div>

# %% [markdown]
# Muestra una superficie tridimensional que representa la solución numérica de la ecuación de calor *u(x,t)*
#
# La superficie evoluciona con la temperatura en un dominio 1D a lo largo del tiempo, ya que para cada punto *(x,t)* existe un valor de temperatura *u(x,t)* la gráfica nos muestra cómo este disminuye en el tiempo

# %% [markdown]
# Ejercicio 6: Hay un ligero detalle con la precisión de estas gráficas, ¿cuál?

# %% [markdown]
# Las gráficas representan una interpolación continua de una solución que en realidad es discreta
